# %%
import os
os.chdir('/content/drive/MyDrive/Kaggle')
os.getcwd()
# Out:
# '/content/drive/MyDrive/Kaggle'

# %% [markdown]
# # Downloading Data from Kaggle

# %%
#!kaggle competitions download -c optiver-trading-at-the-close

# %%
#!unzip \*.zip && rm*.zip

# %% [markdown]
# # Loading Data into Dataframe

# %%
import pandas as pd

data = pd.read_csv('train.csv', na_values= ["NA", "N/A", "NaN", "missing", "None"])
data = pd.DataFrame(data=data)
data
# Out:
#          stock_id  date_id  seconds_in_bucket  imbalance_size  \
# 0               0        0                  0      3180602.69
# 1               1        0                  0       166603.91
# 2               2        0                  0       302879.87
# 3               3        0                  0     11917682.27
# 4               4        0                  0       447549.96
# ...           ...      ...                ...             ...
# 5237975       195      480                540      2440722.89
# 5237976       196      480                540       349510.47
# 5237977       197      480                540            0.00
# 5237978       198      480                540      1000898.84
# 5237979       199      480                540      1884285.71
#
#          imbalance_buy_sell_flag  reference_price  matched_size  far_price  \
# 0                              1         0.999812   13380276.64        NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5237980 entries, 0 to 5237979
# Data columns (total 17 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   stock_id                 int64
#  1   date_id                  int64
#  2   seconds_in_bucket        int64
#  3   imbalance_size           float64
#  4   imbalance_buy_sell_flag  int64
#  5   reference_price          float64
#  6   matched_size             float64
#  7   far_price                float64
#  8   near_price               float64
#  9   bid_price                float64
#  10  bid_size                 float64
#  11  ask_price                float64
#  12  ask_size                 float64
#  13  wap                      float64
#  14  target                   float64
#  15  time_id                  int64
#  16  row_id                   object
# dtypes: float64(11), int64(5), object(1)
# memory usage: 679.4+ MB

# %%
null_counts = data.isnull().sum()

print(null_counts)
# Out:
# stock_id                         0
# date_id                          0
# seconds_in_bucket                0
# imbalance_size                 220
# imbalance_buy_sell_flag          0
# reference_price                220
# matched_size                   220
# far_price                  2894342
# near_price                 2857180
# bid_price                      220
# bid_size                         0
# ask_price                      220
# ask_size                         0
# wap                            220
# target                          88
# time_id                          0
# row_id                           0
# dtype: int64

# %%
data.describe()
# Out:
#            stock_id       date_id  seconds_in_bucket  imbalance_size  \
# count  5.237980e+06  5.237980e+06       5.237980e+06    5.237760e+06
# mean   9.928856e+01  2.415100e+02       2.700000e+02    5.715293e+06
# std    5.787176e+01  1.385319e+02       1.587451e+02    2.051591e+07
# min    0.000000e+00  0.000000e+00       0.000000e+00    0.000000e+00
# 25%    4.900000e+01  1.220000e+02       1.300000e+02    8.453415e+04
# 50%    9.900000e+01  2.420000e+02       2.700000e+02    1.113604e+06
# 75%    1.490000e+02  3.610000e+02       4.100000e+02    4.190951e+06
# max    1.990000e+02  4.800000e+02       5.400000e+02    2.982028e+09
#
#        imbalance_buy_sell_flag  reference_price  matched_size     far_price  \
# count             5.237980e+06     5.237760e+06  5.237760e+06  2.343638e+06
# mean             -1.189619e-02     9.999955e-01  4.510025e+07  1.001713e+00
# std               8.853374e-01     2.532497e-03  1.398413e+08  7.214705e-01
# ...

# %%
x=data.drop(['target'],axis=1)
y=data['target']

# %%
def data_preprocessing(x):
    x.drop(['far_price','near_price','row_id','time_id'],axis=1,inplace=True)
    for i in x.columns:
        if x[i].isnull().sum()>0:
            x[i].fillna(x[i].median(),inplace=True)
    return x

# %%
x=data_preprocessing(x)
y.fillna(y.median(),inplace=True)

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Create an instance of StandardScaler
scaler = StandardScaler()

# Fit and transform the DataFrame
x_scaled = scaler.fit_transform(x)

# Create a new DataFrame with scaled values
x = pd.DataFrame(x_scaled, columns=x.columns)

# %%
x
# Out:
#          stock_id   date_id  seconds_in_bucket  imbalance_size  \
# 0       -1.715665 -1.743353           -1.70084       -0.123541
# 1       -1.698386 -1.743353           -1.70084       -0.270454
# 2       -1.681106 -1.743353           -1.70084       -0.263811
# 3       -1.663827 -1.743353           -1.70084        0.302336
# 4       -1.646547 -1.743353           -1.70084       -0.256760
# ...           ...       ...                ...             ...
# 5237975  1.653854  1.721553            1.70084       -0.159605
# 5237976  1.671134  1.721553            1.70084       -0.261538
# 5237977  1.688413  1.721553            1.70084       -0.278575
# 5237978  1.705693  1.721553            1.70084       -0.229787
# 5237979  1.722973  1.721553            1.70084       -0.186728
#
#          imbalance_buy_sell_flag  reference_price  matched_size  bid_price  \
# 0                       1.142950        -0.072474     -0.226823   0.034293
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %% [markdown]
# # BASELINE Models

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# # Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, mean_absolute_error

scorer = make_scorer(mean_absolute_error, greater_is_better=False)

param_grid_dt = {
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
}

dt = DecisionTreeRegressor()
grid_search_dt = GridSearchCV(dt, param_grid_dt, scoring=scorer, cv=5)

grid_search_dt.fit(x_train, y_train)

best_params_dt = grid_search_dt.best_params_
best_estimator_dt = grid_search_dt.best_estimator_

# %%
print("Optimal parameters for Decision Tree Regression Model are:",best_params_dt)
#best_params_dt
#best_estimator_dt

# %%
DTR=DecisionTreeRegressor(max_depth=10, min_samples_leaf=1, min_samples_split=5)

DTR.fit(x_train,y_train)

pred_DTR=DTR.predict(x_test)

print("*********************************************************")
print("MAE score of Decision Tree Regression Model =",mean_absolute_error(y_test,pred_DTR))
print("*********************************************************")
# Out:
# *********************************************************
# MAE score of Decision Tree Regression Model = 6.356991851206895
# *********************************************************
